# %% [markdown]
# # Programmare in Python
#
# ## Esercizi: Plots

# %% [markdown]
# __1 - Fate il grafico della funzione $f = x^3 + x^2 -2\,x$ in $ -4 \le x \le 4$. Il titolo del grafico sia "Funzione", il titolo dell'asse x sia "x" e quello dell'asse y sia "f(x)".__

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-4,4,0.001)
y = x**3 + x**2 - 2*x

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,10))

ax.set_ylabel('$f(x)$')
ax.set_xlabel('$x$')
ax.set_title('Funzione')
ax.grid()
ax.plot(x,y);

# %% [markdown]
# __2 - Fare un unico grafico delle funzioni $f_1 = \sin(x)$, in blu, e $f_2 = \sin(2 x)$, in rosso.__

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-2*np.pi,2*np.pi,0.001)


fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,5))


ax.set_ylabel('$f(x)$')
ax.set_xlabel('$x$')
ax.set_title('Sin e Cos')
ax.grid()
ax.plot(x,np.sin(x),c='b');
ax.plot(x,np.cos(x),c='r');

# %% [markdown]
# __3 - Fare il grafico delle cinque funzioni $f_n =  \frac{(x +n)^n}{n!}$  per $n = 1,2,3,4,5$ e $x$ fra zero e 2, in un unico plot. Inserire delle legende opportune.__

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

x = np.arange(0,3,0.001)
n = np.arange(1,6)

# env
fig, ax = plt.subplots()
ax.set_ylabel('$f(x)$')
ax.set_xlabel('$x$')
ax.set_title('Titolo')
ax.grid()

# labels
plt.text(3.2,0, r'$n=1$', {'color': 'b', 'fontsize': 10})
plt.text(3.2,10, r'$n=2$', {'color': 'tab:orange', 'fontsize': 10})
plt.text(3.2,25, r'$n=3$', {'color': 'g', 'fontsize': 10})
plt.text(3.2,100, r'$n=4$', {'color': 'r', 'fontsize': 10})
plt.text(3.2,270, r'$n=5$', {'color': 'tab:purple', 'fontsize': 10})


# plots
for n in range(1,6):
    y = (x+n)**n/(math.factorial(n))
    ax.plot(x,y);

# %% [markdown]
# __4 - Create due plot affiancati. Nel primo fate il grafico di $f_1 = \frac{x^2}{1+x^4}$ in $ -4 \le x \le 4$. Nel secondo fate il grafico di $f_2 = \log (f_1)$ in $ 1 \le x \le 10$. Inserite la griglia nei due plot.__

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.arange(-4,5,0.01)
def f1(x1):  
    return (x1**2)/(1 + x1**4)


x2 = np.arange(1,11,0.01)
def f2(x2):
    return np.log(f1(x2))


# env
fig1, (ax1,ax2) = plt.subplots(nrows=1, ncols=2)


ax1.grid()
ax1.plot(x1,f1(x1));

ax2.set_xscale('log')
ax2.plot(x2,f2(x2));

# %% [markdown]
# __5 - Fate un unico grafico delle funzioni $f_1 = x^2 \,\sin(x)$ e $f_2 = x^4\,\sin(2 x)$ per $ 0 \le x \le 10$ usando una scala logaritmica sull'asse y. Inserire i titoli degli assi e le legende.__

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0,11,0.001)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,5))

ax.set_yscale('log')
ax.set_ylabel('$f(x)$')
ax.set_xlabel('$x$')
ax.set_title('Sin e Cos')
ax.grid()
ax.plot(x,(x**2)*np.sin(x),c='b')
ax.plot(x,(x**4)*np.sin(2*x),c='r')

# %% [markdown]
# __6 - Costruite un array x0 che contenga 101 punti equidistanti fra 0 e 4. Costruite l'array y0 = x\*\*2 + 3\*x. Fate lo scatter plot di y0 in funzione di x0.__

# %%
x0 = np.linspace(0,4,101)
y0 = x0**2 + 3*x0

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,10))
ax.scatter(x0,y0)

# %% [markdown]
# __7 - Create quattro plot disposti su due righe. Nei quattro plot il grafico di $f_n = \frac{x^n -3}{1+x^4}$ per $n$ = 1,2,3,4 in $\, -4 \le x \le 4\,$. Inserite i titoli e i titoli degli assi in ciascuno dei quattro grafici.____

# %%
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(10,10))

x = np.arange(1,5)
y = (x**n - 3)/(1+x**4)

ax1.scatter(x,y)

# %% [markdown]
# __8 - In un unico grafico, disegnate le funzioni $f_n = x^n$ con $n$ in `range(1,5)` e $0 < x 4$ .  Inserite gli elementi grafici opportuni per rendere la figura comprensibile.__

# %%
x = np.arange(0,5)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,10))
for i in range(1,5):
    ax.plot(x,x**i,label=f"$y=x^{i}$")
    ax.legend()

# %% [markdown]
# __9 - Fate il plot di $\tan (x)$.__ (D.J.Pine, Introduction to Python for Science and Engineering, 6.2.3)

# %%
x = np.arange(0,np.pi,0.001)
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,10))

ax.plot(x,np.sin(x)/np.cos(x))

# %% [markdown]
# __10 -Fate, in un unico plot, il grafico di un cerchio di raggio 2 centrato nell'origine e di un esagono inscritto nel cerchio.__

# %%
ang = np.linspace(0, 2 * np.pi, 100)
r = 2
x = r * np.cos(ang)
y = r * np.sin(ang)

# Creazione dei punti dell'esagono inscritto nel cerchio
lato_esagono = 2 * r * np.sin(np.pi / 6)  
angoli_esagono = np.linspace(0, 2 * np.pi, 7)

x_esagono = r * np.cos(angoli_esagono)
y_esagono = r * np.sin(angoli_esagono)

# Creazione del grafico
plt.figure(figsize=(6, 6))
plt.plot(x_cerchio, y_cerchio, label='Cerchio')
plt.plot(x_esagono, y_esagono, label='Esagono')


plt.legend()
